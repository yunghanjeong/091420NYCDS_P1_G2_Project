# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# !ls data
# Out:
# bom.movie_gross.csv.gz        imdb.title.ratings.csv.gz
# imdb.name.basics.csv.gz       imdb.title_rating_summary.csv
# imdb.title.akas.csv.gz        rt.movie_info.tsv.gz
# imdb.title.basics.csv.gz      rt.reviews.tsv.gz
# imdb.title.crew.csv.gz        tmdb.movies.csv.gz
# imdb.title.principals.csv.gz  tn.movie_budgets.csv.gz

# %%
df1 = pd.read_csv('data/bom.movie_gross.csv.gz')
df1.head(2)
# Out:
#                         title studio  domestic_gross foreign_gross  year
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1  Alice in Wonderland (2010)     BV     334200000.0     691300000  2010

# %%
import sqlite3
conn = sqlite3.connect('data/bom.movie_gross.csv.gz')
cur = conn.cursor()

# %%
# df2 = pd.read_csv('data/imdb.name.basics.csv.gz')
# df2.head(2)

# %%
df3 = pd.read_csv('data/imdb.title.akas.csv.gz')
df3.head(2)
# Out:
#     title_id  ordering              title region language        types  \
# 0  tt0369610        10      Джурасик свят     BG       bg          NaN
# 1  tt0369610        11  Jurashikku warudo     JP      NaN  imdbDisplay
#
#   attributes  is_original_title
# 0        NaN                0.0
# 1        NaN                0.0

# %%
# df4 = pd.read_csv('data/imdb.title.crew.csv.gz')
# df4.head(2)

# %%
df5 = pd.read_csv('data/imdb.name.basics.csv.gz')
df5.head(2)
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
#
#                            primary_profession  \
# 0   miscellaneous,production_manager,producer
# 1  composer,music_department,sound_department
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940

# %%
# df6 = pd.read_csv('data/imdb.title.principals.csv.gz')
# df6.head(2)

# %%
# df7 = pd.read_csv('data/rt.reviews.tsv.gz', delimiter='\t', encoding='windows-1254')
# df7.head(2)

# %%
## genre, theater date, dvd date, box office $, run time
df8 = pd.read_csv('data/rt.movie_info.tsv.gz', delimiter='\t', encoding='windows-1254')
df8.tail()
# Out:
#         id                                           synopsis rating  \
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# ...

# %%
# tmdb genre ids, title name, release date
df9 = pd.read_csv('data/tmdb.movies.csv.gz')
df9.head(2)
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610

# %%
#realease date, movie, budget, worldwide gross
df10 = pd.read_csv('data/tn.movie_budgets.csv.gz')
df10.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875

# %%
# tmdb genre ids, title name, release date
df9 = pd.read_csv('data/tmdb.movies.csv.gz')
df9.head(2)
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610

# %%
# df_i_basic = pd.read_csv('data/imdb.title.basics.csv.gz') 
# df_i_basic.head()

# %%
# df_i_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz') 
# df_i_ratings.head()

# %%
# merged between title.basic and title.rating (df4 & df7)
# tconst, primary title, original title, start year, running minutes, genres
# 
df11 = pd.read_csv('data/imdb.title_rating_summary.csv')
df11.head(2)
# Out:
#    Unnamed: 0     tconst                    primary_title   original_title  \
# 0           0  tt0063540                        Sunghursh        Sunghursh
# 1           1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din
#
#    start_year  runtime_minutes              genres  averagerating  numvotes
# 0        2013            175.0  Action,Crime,Drama            7.0        77
# 1        2019            114.0     Biography,Drama            7.2        43
