# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
##list files from data folder 

# !ls data
# Out:
# bom.movie_gross.csv.gz        imdb.title.ratings.csv.gz
# imdb.name.basics.csv.gz       imdb.title_rating_summary.csv
# imdb.title.akas.csv.gz        rt.movie_info.tsv.gz
# imdb.title.basics.csv.gz      rt.reviews.tsv.gz
# imdb.title.crew.csv.gz        tmdb.movies.csv.gz
# imdb.title.principals.csv.gz  tn.movie_budgets.csv.gz

# %%
# df1 = pd.read_csv('data/imdb.name.basics.csv.gz')
# df1.head()

# %%
df2 = pd.read_csv('data/bom.movie_gross.csv.gz')
#df2.head()
df2.shape
# Out:
# (3387, 5)

# %%
## returns row for one movie
df2[df2.title == "Inception"]
# Out:
#        title studio  domestic_gross foreign_gross  year
# 3  Inception     WB     292600000.0     535700000  2010

# %%
df2.fillna(0)
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
## Show all NaN values for foreign_gross
df2[df2.foreign_gross.isnull()]
# Out:
#                                        title      studio  domestic_gross  \
# 222                                  Flipped          WB       1800000.0
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# 269            Grease (Sing-a-Long re-issue)        Par.        366000.0
# 280                          Last Train Home       Zeit.        288000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 222            NaN  2010
# 254            NaN  2010
# ...

# %%
df2['domestic_gross'].dtypes
# Out:
# dtype('float64')

# %%
df2['foreign_gross'].dtypes
# Out:
# dtype('O')

# %%
#df2_new = df2.replace(NaN,0) -- this did not work
df2_new = df2.fillna(0)
df2_new
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# ##

# %%
## change gross strings to floats
df2_new['domestic_gross'] = df2_new['domestic_gross'].astype(float)

## this one was a bitch:
df2_new['foreign_gross'] = pd.to_numeric(df2_new['foreign_gross'],errors='coerce')

# %%
df2_new['total_gross']= df2_new.domestic_gross + df2_new.foreign_gross
df2_new.tail()
# Out:
#                             title      studio  domestic_gross  foreign_gross  \
# 3382                    The Quake       Magn.          6200.0            0.0
# 3383  Edward II (2018 re-release)          FM          4800.0            0.0
# 3384                     El Pacto        Sony          2500.0            0.0
# 3385                     The Swan  Synergetic          2400.0            0.0
# 3386            An Actor Prepares       Grav.          1700.0            0.0
#
#       year  total_gross  total_gross_conv  foreign_gross_conv  \
# 3382  2018       6200.0            0.0062                 0.0
# 3383  2018       4800.0            0.0048                 0.0
# 3384  2018       2500.0            0.0025                 0.0
# 3385  2018       2400.0            0.0024                 0.0
# 3386  2018       1700.0            0.0017                 0.0
#
#       domestic_gross_conv
# 3382               0.0062
# 3383               0.0048
# 3384               0.0025
# ...

# %%
## title id, title name, 

df3 = pd.read_csv('data/imdb.title.akas.csv.gz')
df3.head()
#df3['title'].str.contains('avatar').any()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
#df3["Indexes"]= df3["title"].str.find('avatar')

# %%
df3["Indexes"]= df3["title"].str.find('Hannah')

# %%
df4 = pd.read_csv('data/imdb.title.basics.csv.gz')
df4.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df5 = pd.read_csv('data/imdb.title.principals.csv.gz')
df5.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
df6 = pd.read_csv('data/imdb.title.ratings.csv.gz')
df6.head(10)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# 5   tt1069246            6.2       326
# 6   tt1094666            7.0      1613
# 7   tt1130982            6.4       571
# 8   tt1156528            7.2       265
# 9   tt1161457            4.2       148

# %%
df7 = pd.read_csv('data/rt.reviews.tsv.gz', delimiter='\t', encoding='windows-1254')
df7.head(5)
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
df8 = pd.read_csv('data/rt.movie_info.tsv.gz', delimiter='\t', encoding='windows-1254')
df8.head(20)
# Out:
#     id                                           synopsis rating  \
# 0    1  This gritty, fast-paced, and innovative police...      R
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 2    5  Illeana Douglas delivers a superb performance ...      R
# 3    6  Michael Douglas runs afoul of a treacherous su...      R
# 4    7                                                NaN     NR
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 8   14  "Love Ranch" is a bittersweet love story that ...      R
# 9   15  When a diamond expedition in the Congo is lost...  PG-13
# 10  17                                                NaN    NaN
# 11  18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12  19  While Microsoft may be the biggest software co...     NR
# ...

# %%
df9 = pd.read_csv('data/tmdb.movies.csv.gz')
df9.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df10 = pd.read_csv('data/tn.movie_budgets.csv.gz')
df10.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
df11 = pd.read_csv('data/imdb.title_rating_summary.csv') 
df11.tail()
# Out:
#        Unnamed: 0     tconst               primary_title  \
# 73851       73851  tt9913084            Diabolik sono io
# 73852       73852  tt9914286           Sokagin Çocuklari
# 73853       73853  tt9914642                   Albatross
# 73854       73854  tt9914942  La vida sense la Sara Amat
# 73855       73855  tt9916160                  Drømmeland
#
#                    original_title  start_year  runtime_minutes        genres  \
# 73851            Diabolik sono io        2019             75.0   Documentary
# 73852           Sokagin Çocuklari        2019             98.0  Drama,Family
# 73853                   Albatross        2017              NaN   Documentary
# 73854  La vida sense la Sara Amat        2019              NaN           NaN
# 73855                  Drømmeland        2019             72.0   Documentary
#
#        averagerating  numvotes
# 73851            6.2         6
# 73852            8.7       136
# 73853            8.5         8
# ...

# %%
df11[df11["numvotes"] > 100].sort_values("averagerating", ascending = False)
# Out:
#        Unnamed: 0     tconst                      primary_title  \
# 73343       73343  tt9537008                  Gini Helida Kathe
# 65296       65296  tt7131622  Once Upon a Time ... in Hollywood
# 71545       71545  tt8718580                          Eghantham
# 73062       73062  tt9343826                Ananthu V/S Nusrath
# 73583       73583  tt9680166          Yeh Suhaagraat Impossible
# ...           ...        ...                                ...
# 55323       55323  tt5620038                       A Rain Woman
# 13917       13917  tt1945118                 In a Lonely Planet
# 57307       57307  tt5874352              Utsuroi no hyôhonbako
# 49011       49011  tt4837074            Ritoru Kyouta no bouken
# 12618       12618  tt1872215                 Tunnel Rendez-vous
#
#                           original_title  start_year  runtime_minutes  \
# 73343                  Gini Helida Kathe        2019            138.0
# ...

# %%
df2_new.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
df2_new['total_gross_conv'] = df2_new.total_gross / 1000000
df2_new['foreign_gross_conv'] = df2_new.foreign_gross / 1000000
df2_new['domestic_gross_conv'] = df2_new.domestic_gross / 1000000

df2_new.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross  total_gross_conv  foreign_gross_conv  \
# 0    652000000.0  2010  1.067000e+09            1067.0               652.0
# 1    691300000.0  2010  1.025500e+09            1025.5               691.3
# 2    664300000.0  2010  9.603000e+08             960.3               664.3
# 3    535700000.0  2010  8.283000e+08             828.3               535.7
# 4    513900000.0  2010  7.526000e+08             752.6               513.9
#
#    domestic_gross_conv
# 0                415.0
# 1                334.2
# ...

# %%
## Check movie title
#df2_new[df2_new.title == "Dark Phoenix"]

## Descending total_gross
df2_new.sort_values("total_gross_conv", ascending = False)
df2_new.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross  total_gross_conv  foreign_gross_conv  \
# 0    652000000.0  2010  1.067000e+09            1067.0               652.0
# 1    691300000.0  2010  1.025500e+09            1025.5               691.3
# 2    664300000.0  2010  9.603000e+08             960.3               664.3
# 3    535700000.0  2010  8.283000e+08             828.3               535.7
# 4    513900000.0  2010  7.526000e+08             752.6               513.9
#
#    domestic_gross_conv
# 0                415.0
# 1                334.2
# ...

# %%
## merge df2_new (gross) with df11
